# %% [markdown]
# # Fantasy Football Draft Guide

# %%
# Import libraries
from utils import *
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from warnings import simplefilter
from datetime import *

# Configure Pandas settings
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# Set pbp data read option
read_local_data = False

# %% [markdown]
# ## Data Imports

# %%
# Set filepath for config yaml
filepath = "fantasy_config.yml"

# Read yaml and flatten
env_dict = flatten_dict(read_yaml(filepath))
env_dict
# Out:
# {'seasons': [2022, 2021],
#  'rec_rec': 1,
#  'rec_td': 6,
#  'rec_yd': 0.1,
#  'rec_twoPointConv': 2,
#  'rush_td': 6,
#  'rush_yd': 0.1,
#  'rush_lostFumble': -2,
#  'rush_twoPointConv': 2,
#  'pass_td': 4,
#  'pass_yd': 0.04,
#  'pass_int': -1,
#  'pass_twoPointConv': 2,
#  'kick_fg_00_19': 3,
#  'kick_fg_20_29': 3,
#  'kick_fg_30_39': 3,
#  'kick_fg_40_49': 4,
#  'kick_fg_50_xx': 5,
#  'kick_fg_miss': -1,
#  'kick_pat_make': 1,
#  'kick_pat_miss': -1,
#  'def_td': 6,
#  'def_sack': 1,
#  'def_int': 2,
#  'def_forceFum': 1,
#  'def_recovFum': 2,
#  'def_recovFumTD': 6,
#  'def_safety': 2,
#  'def_allow_00_00': 10,
#  'def_allow_01_06': 7,
#  'def_allow_07_13': 4,
#  'def_allow_14_20': 1,
#  'def_allow_21_27': 0,
#  'def_allow_28_34': -1,
#  'def_allow_35_xx': -4,
#  'spec_td': 6,
#  'spec_recovFumTD': 6,
#  'spec_blockKick': 2,
#  'spec_forceFum': 1,
#  'spec_recovFum': 1}

# %%
pbp_enrich_df = import_enrich_pbp_data(years=env_dict['seasons'], regular=True)

# %%
pbp_expand_df = participation_expander(pbp_enrich_df)

# %%
defense_player_columns = []
offense_player_columns = []
for i in range(1,12):
    defense_string = 'defense_player_'+str(i)
    offense_string = 'offense_player_'+str(i)
    defense_player_columns.extend([defense_string])
    offense_player_columns.extend([offense_string])
print(defense_player_columns,offense_player_columns)

# %%
all_player_columns = defense_player_columns + offense_player_columns
all_player_columns

# %%
pbp_single_game_df = pbp_enrich_df[pbp_enrich_df['game_id']=='2022_09_TEN_KC'] \
                        .sort_values(by=['play_id'], ascending=True)

def_split_df = (pbp_single_game_df['defense_players'].str.split(';', expand=True) \
                  .fillna(np.nan) \
                  .rename(columns={i: col for i,col in enumerate(defense_player_columns)}))

off_split_df = (pbp_single_game_df['offense_players'].str.split(';', expand=True) \
                  .fillna(np.nan) \
                  .rename(columns={i: col for i,col in enumerate(offense_player_columns)}))

test_df = pbp_single_game_df.join(def_split_df, how='left').join(off_split_df, how='left')

test_df

# %%
test_df['season'].min()

# %%
players_df = import_players_data(env_dict['seasons'])

players_df_trunc = players_df[['player_id','season','player_name','depth_chart_position']].add_prefix('p_')

players_df_trunc

# %%
for column in all_player_columns:
    left_columns = ['season', column]
    right_columns = ['p_season', 'p_player_id']
    new_name = column + '_name'
    new_position = column + '_position'
    test_df = test_df.merge(players_df_trunc, how='left', left_on=left_columns, right_on=right_columns) \
                     .drop(columns=right_columns) \
                     .rename(columns={'p_player_name':new_name, 'p_depth_chart_position':new_position})

test_df

# %%
off_agg_df = import_off_agg_data(years=env_dict['seasons'], regular=True, level='season')
off_agg_df.sort_values(by=['season','fantasy_total_pts'], ascending=[True, False])
# Out:
# 2022 done.
# 2021 done.
# Downcasting floats.
# Adding participation data.
# Adding fantasy data.
# Aggregating data.
#       season   player_id  fantasy_rush_pts  fantasy_rec_pts  fantasy_pass_pts  \
# 156     2021  00-0033908              1.80           435.70              0.00
# 0       2021  00-0019596             12.50             0.00            384.64
# 218     2021  00-0034857             59.10             0.00            320.28
# 295     2021  00-0036223            285.10            88.00              0.00
# 10      2021  00-0026498             -0.70             0.00            359.44
# ...      ...         ...               ...              ...               ...
# 482     2022  00-0033936             -0.10             0.00              0.00
# 1197    2022  00-0033319              0.00             0.00             -0.12
# 388     2022  00-0026197             -0.30             0.00              0.00
# 433     2022  00-0032496             -0.30             0.00              0.00
# 528     2022  00-0035042             -0.30             0.00              0.00
#
#       fantasy_total_pts  carries  rushing_yards  rushing_tds  targets  \
# 156              437.50     4.00          18.00          NaN   192.00
# 0                397.14     7.00          14.00         2.00      NaN
# 218              379.38    67.00         342.00         6.00     1.00
# 295              373.10   332.00        1811.00        18.00    52.00
# 10               358.74     7.00          11.00          NaN      NaN
# ...                 ...      ...            ...          ...      ...
# 482               -0.10      NaN            NaN          NaN      NaN
# 1197              -0.12      NaN            NaN          NaN      NaN
# 388               -0.30      NaN            NaN          NaN      NaN
# 433               -0.30     1.00          -3.00          NaN      NaN
# 528               -0.30     2.00          -3.00          NaN      NaN
#
#       receptions  receiving_yards  receiving_tds first_name last_name  \
# 156       145.00          1947.00          16.00     Cooper      Kupp
# 0            NaN              NaN            NaN        Tom     Brady
# 218         0.00              NaN            NaN     Joshua     Allen
# 295        40.00           360.00           2.00   Jonathan    Taylor
# 10           NaN              NaN            NaN       John  Stafford
# ...          ...              ...            ...        ...       ...
# 482          NaN              NaN            NaN      Casey  Beathard
# 1197         NaN              NaN            NaN        NaN       NaN
# 388          NaN              NaN            NaN       Chad     Henne
# 433          NaN              NaN            NaN        NaN       NaN
# 528          NaN              NaN            NaN        NaN       NaN
#
#            player_name height  weight  years_exp draft_club  draft_number  \
# 156        Cooper Kupp     74  208.00       4.00         LA         69.00
# 0            Tom Brady     76  225.00      21.00         NE        199.00
# 218         Josh Allen     77  237.00       3.00        BUF          7.00
# 295    Jonathan Taylor     70  221.00       1.00        IND         41.00
# 10    Matthew Stafford     75  220.00      12.00        DET          1.00
# ...                ...    ...     ...        ...        ...           ...
# 482      C.J. Beathard     74  215.00       5.00         SF        104.00
# 1197               NaN    NaN     NaN        NaN        NaN           NaN
# 388         Chad Henne     75  222.00      14.00        MIA         57.00
# 433                NaN    NaN     NaN        NaN        NaN           NaN
# 528                NaN    NaN     NaN        NaN        NaN           NaN
#
#       age_sos position depth_chart_position  jersey_number
# 156     28.00       WR                   WR          10.00
# 0       44.00       QB                   QB          12.00
# 218     25.00       QB                   QB          17.00
# 295     22.00       RB                   RB          28.00
# 10      33.00       QB                   QB           9.00
# ...       ...      ...                  ...            ...
# 482     28.00       QB                   QB           3.00
# 1197      NaN      NaN                  NaN            NaN
# 388     37.00       QB                   QB           4.00
# 433       NaN      NaN                  NaN            NaN
# 528       NaN      NaN                  NaN            NaN
#
# [1205 rows x 25 columns]

# %%
# pbp_fantasy_df[pbp_fantasy_df['game_id']=='2022_09_TEN_KC'].sort_values(by=['play_id'], ascending=True) \
#     .to_csv(path_or_buf='data/pbp_fantasy_2022_09_TEN_KC.csv')

# %%
# ngs_rush_df = nfl.import_ngs_data(stat_type='rushing', years=env_dict['seasons'])
# ngs_rec_df = nfl.import_ngs_data(stat_type='receiving', years=env_dict['seasons'])
# ngs_pass_df = nfl.import_ngs_data(stat_type='passing', years=env_dict['seasons'])

# %%
# ngs_rush_df[(ngs_rush_df['week']==0)&(ngs_rush_df['season_type']=='REG')] \
#     .sort_values(by=['season','rush_yards_over_expected_per_att'],ascending=[False,False]).head(200)

# %%
# snap_counts_df = nfl.import_snap_counts(env_dict['seasons'])
# snap_counts_df

# %%
# combine_df = nfl.import_combine_data(years=env_dict['seasons'])
# combine_df

# %%
# Enrich off_agg_df
off_agg_df['fantasy_total_pts'] = off_agg_df['fantasy_rush_pts'] + \
                                  off_agg_df['fantasy_rec_pts'] + \
                                  off_agg_df['fantasy_pass_pts']
off_agg_df['overall_rank'] = off_agg_df.groupby('season')['fantasy_total_pts'] \
                                       .rank(method='dense', ascending=False) \
                                       .astype(int)
off_agg_df['rush_rank'] = off_agg_df.groupby('season')['fantasy_rush_pts'] \
                                    .rank(method='dense', ascending=False) \
                                    .astype(int)
off_agg_df['rec_rank'] = off_agg_df.groupby('season')['fantasy_rec_pts'] \
                                   .rank(method='dense', ascending=False) \
                                   .astype(int)
off_agg_df['pass_rank'] = off_agg_df.groupby('season')['fantasy_pass_pts'] \
                                    .rank(method='dense', ascending=False) \
                                    .astype(int)
off_agg_df['position_rank'] = off_agg_df.groupby(by=['position','season'])['fantasy_total_pts'] \
                                        .rank(method='dense', ascending=False) \
                                        .astype(int)
off_agg_df['fantasy_total_pts_nextYear'] = off_agg_df.sort_values(by=['player_id','season'], ascending=[True,False]) \
                                                     .groupby(['player_id'])['fantasy_total_pts'].shift(1)
off_agg_df['fantasy_total_pts_nextYearDiff'] = off_agg_df['fantasy_total_pts'] - \
                                               off_agg_df['fantasy_total_pts_nextYear']

off_agg_df[(off_agg_df['position']=='RB')&(off_agg_df['season']==2021)].sort_values(by=['position_rank'], 
                                                                                    ascending=True)
# Out:
#      season   player_id  fantasy_rush_pts  fantasy_rec_pts  fantasy_pass_pts  \
# 295    2021  00-0036223            285.10            88.00              0.00
# 361    2021  00-0036893            162.00           138.70              0.00
# 154    2021  00-0033897            202.50            91.40              0.00
# 137    2021  00-0033553            165.20            91.60              0.00
# 144    2021  00-0033856            129.20           126.40              0.00
# 347              25.70    15.00          74.00         2.00     5.00
# 108              20.70    17.00          79.00         1.00     6.00
# 242              19.70    21.00         105.00         1.00     6.00
# 322              17.00    33.00         102.00          NaN     7.00
# 344              15.60    36.00          87.00         1.00     2.00
# 66               14.70     8.00          26.00         1.00     3.00
# 163              13.50    28.00         104.00          NaN     3.00
# 236              13.10    36.00          98.00          NaN     4.00
# 164              12.90    28.00         101.00          NaN     5.00
# 241              12.60    15.00          80.00          NaN     4.00
# 354              11.00    14.00          61.00          NaN     5.00
# 106               9.90     2.00           0.00         1.00     5.00
# 126               9.20     5.00          21.00          NaN     1.00
# 99                8.70     5.00          25.00          NaN     5.00
# 245               6.50    15.00          51.00          NaN     2.00
# 210               6.40    12.00          36.00          NaN     7.00
# 184               6.40     1.00           4.00         1.00      NaN
# 181               5.30     5.00           9.00          NaN     4.00
# 306               5.10    13.00          51.00          NaN     1.00
# 92                4.80     4.00          16.00          NaN     2.00
# 103               4.60     1.00           1.00          NaN     3.00
# 328               4.30     5.00           3.00          NaN     3.00
# 346               3.90    10.00          24.00          NaN     2.00
# 308               3.80     2.00           7.00          NaN     2.00
# 303               3.10     8.00          31.00          NaN      NaN
# 812               3.00      NaN            NaN          NaN     1.00
# 315               2.40     3.00           3.00          NaN     1.00
# 338               2.00     1.00           4.00          NaN     1.00
# 211               1.30     2.00          13.00          NaN      NaN
# 357               0.50     2.00           5.00          NaN      NaN
# 171               0.40     3.00           4.00          NaN      NaN
# 40                0.00     4.00           0.00          NaN      NaN
#
#      receptions  receiving_yards  receiving_tds   first_name        last_name  \
# 295       40.00           360.00           2.00     Jonathan           Taylor
# 361       74.00           467.00           3.00        Najee           Harris
# 154       42.00           314.00           3.00          Joe            Mixon
# 137       37.00           366.00           3.00        James           Conner
# 144       69.00           454.00           2.00      Leonard        Fournette
# 113       47.00           273.00           2.00      Ezekiel          Elliott
# 155       47.00           439.00           5.00        Alvin           Kamara
# 47        52.00           548.00           5.00  Cordarrelle        Patterson
# 272       54.00           348.00            NaN       Joshua           Jacobs
# 313       42.00           294.00           3.00      Antonio           Gibson
# 125       52.00           391.00           6.00        Aaron            Jones
# 305       62.00           450.00           2.00      D'Andre            Swift
# 207       20.00           174.00           1.00     Nicholas            Chubb
# 266       18.00           132.00            NaN       Damien           Harris
# 79        28.00           213.00           2.00       Melvin           Gordon
# 379       43.00           316.00           3.00      Javonte         Williams
# 152       34.00           224.00            NaN       Dalvin             Cook
# 239       40.00           228.00           1.00        Devin       Singletary
# 271       42.00           301.00            NaN        David       Montgomery
# 97        18.00           154.00            NaN      Derrick            Henry
# 301       34.00           313.00           2.00      Algiers           Dillon
# 247       49.00           234.00           4.00        Myles           Gaskin
# 337       19.00           137.00           1.00       Elijah         Mitchell
# 269       29.00           176.00           3.00      Darrell        Henderson
# 240       39.00           337.00            NaN         Tony          Pollard
# 367       36.00           307.00            NaN      Michael           Carter
# 215       41.00           263.00           2.00       Saquon          Barkley
# 58        34.00           190.00           1.00      Devonta          Freeman
# 216       21.00           128.00           1.00         Sony           Michel
# 201       43.00           311.00            NaN        Chase          Edmonds
# 107       40.00           268.00           1.00     Devontae           Booker
# 75        44.00           259.00           1.00      Michael            Davis
# 336       25.00           174.00           1.00        Chuba          Hubbard
# 122       37.00           343.00           1.00    Christian        McCaffrey
# 222       32.00           228.00           1.00    Alexander         Mattison
# 203        6.00            48.00            NaN      Rashaad            Penny
# 366       33.00           253.00           1.00      Kenneth         Gainwell
# 162       26.00           157.00            NaN       Jamaal         Williams
# 259       34.00           372.00           2.00           Ty          Johnson
# 358       14.00           123.00            NaN    Rhamondre        Stevenson
# 183       40.00           300.00           1.00       Nyheim            Hines
# 320       19.00           129.00           2.00        Clyde  Edwards-Helaire
# 238       26.00           158.00            NaN        Miles          Sanders
# 20        27.00           162.00            NaN         Mark           Ingram
# 159       22.00           172.00            NaN       Kareem             Hunt
# 297       23.00           197.00           1.00     Zaccheus             Moss
# 37        25.00           186.00            NaN      Michael         Burkhead
# 43        10.00            75.00            NaN     Latavius           Murray
# 117       30.00           291.00           1.00       Kenyan            Drake
# 187       13.00            83.00            NaN       Boston            Scott
# 160        9.00           123.00            NaN       D'Onta          Foreman
# 76        38.00           289.00           1.00        Ameer         Abdullah
# 191       22.00           178.00            NaN       Justin          Jackson
# 134       27.00           196.00           1.00       Samaje           Perine
# 81        32.00           225.00           1.00        David          Johnson
# 212       10.00            64.00            NaN       Ronald            Jones
# 364       14.00            96.00            NaN       Khalil          Herbert
# 31        30.00           296.00           1.00         Kyle         Juszczyk
# 165       28.00           240.00           1.00       Jeremy        McNichols
# 90         9.00            87.00            NaN         Alex          Collins
# 98         2.00            19.00            NaN       Jordan           Howard
# 330       21.00           133.00            NaN    Demetrius           Dallas
# 86         4.00            41.00            NaN        Randy          Johnson
# 39        23.00           123.00           3.00      Giovani          Bernard
# 261       16.00           161.00            NaN       Travis            Homer
# 73        11.00            49.00            NaN        Tevin          Coleman
# 345       18.00           181.00           2.00     Demetric           Felton
# 356       15.00           151.00           2.00        Chris            Evans
# 139        6.00            29.00            NaN  Christopher           Carson
# 51        12.00            65.00            NaN       Carlos             Hyde
# 332        4.00            26.00            NaN     Ke'Shawn           Vaughn
# 41         5.00            30.00           1.00      Le'Veon             Bell
# 60        13.00            98.00           1.00       Jerick         McKinnon
# 214       10.00            77.00            NaN        Royce          Freeman
# 52        12.00            94.00            NaN        James            White
# 376        3.00            26.00            NaN         Trey           Sermon
# 324        6.00            42.00            NaN          Eno         Benjamin
# 4          4.00             8.00            NaN       Adrian         Peterson
# 347        4.00            23.00            NaN       Jermar        Jefferson
# 108        4.00            28.00            NaN     Jonathan         Williams
# 242        4.00            12.00            NaN       Qadree          Ollison
# 322        5.00            38.00            NaN       Joshua           Kelley
# 344        1.00            -1.00            NaN        Larry         Rountree
# 66         3.00            31.00            NaN      Michael           Burton
# 163        1.00            21.00            NaN        Wayne          Gallman
# 236        2.00            13.00            NaN        Benny            Snell
# 164        2.00             8.00            NaN       Marlon             Mack
# 241        3.00            16.00            NaN      Ryquell         Armstead
# 354        4.00             9.00            NaN         Kene          Nwangwu
# 106        3.00             9.00            NaN         Andy         Janovich
# 126        1.00             1.00           1.00         Alex            Armah
# 99         4.00            22.00            NaN      Wendell        Smallwood
# 245        1.00             4.00            NaN     Trayveon         Williams
# 210        2.00             8.00            NaN        Kalen          Ballage
# 184         NaN              NaN            NaN     Romarius            Smith
# 181        3.00            14.00            NaN       Jaylen          Samuels
# 306        0.00              NaN            NaN        Jason          Huntley
# 92         2.00            12.00            NaN       Dwayne       Washington
# 103        3.00            15.00            NaN        Derek             Watt
# 328        3.00            10.00            NaN          Cam            Akers
# 346        1.00             5.00            NaN        Kylin             Hill
# 308        2.00            11.00            NaN    Darrynton            Evans
# 303         NaN              NaN            NaN     La'Mical           Perine
# 812        1.00            20.00            NaN      Charles           Bawden
# 315        1.00            11.00            NaN      Anthony        McFarland
# 338        1.00             6.00            NaN         Gary       Brightwell
# 211         NaN              NaN            NaN         John            Kelly
# 357         NaN              NaN            NaN         Jake             Funk
# 171         NaN              NaN            NaN      Trenton           Cannon
# 40          NaN              NaN            NaN       Kenjon           Barner
#
#                player_name height  weight  years_exp draft_club  draft_number  \
# 295        Jonathan Taylor     70  221.00       1.00        IND         41.00
# 361           Najee Harris     73  230.00       0.00        PIT         24.00
# 154              Joe Mixon     73  220.00       4.00        CIN         48.00
# 137           James Conner     73  233.00       4.00        PIT        105.00
# 144      Leonard Fournette     72  228.00       4.00        JAX          4.00
# 113        Ezekiel Elliott     72  228.00       5.00        DAL          4.00
# 155           Alvin Kamara     70  215.00       4.00         NO         67.00
# 47   Cordarrelle Patterson     74  238.00       8.00        MIN         29.00
# 272            Josh Jacobs     70  220.00       2.00        OAK         24.00
# 313         Antonio Gibson     74  221.00       1.00        WAS         66.00
# 125            Aaron Jones     69  208.00       4.00         GB        182.00
# 305          D'Andre Swift     69  211.00       1.00        DET         35.00
# 207             Nick Chubb     71  225.00       3.00        CLE         35.00
# 266          Damien Harris     71  215.00       2.00         NE         87.00
# 79           Melvin Gordon     73  215.00       6.00         SD         15.00
# 379       Javonte Williams     70  220.00       0.00        DEN         35.00
# 152            Dalvin Cook     70  210.00       4.00        MIN         41.00
# 239       Devin Singletary     67  203.00       2.00        BUF         74.00
# 271       David Montgomery     71  222.00       2.00        CHI         73.00
# 97           Derrick Henry     75  247.00       5.00        TEN         45.00
# 301            A.J. Dillon     72  250.00       1.00         GB         62.00
# 247           Myles Gaskin     70  200.00       2.00        MIA        234.00
# 337        Elijah Mitchell     70  221.00       0.00         SF        194.00
# 269      Darrell Henderson     68  200.00       2.00         LA         70.00
# 240           Tony Pollard     72  209.00       2.00        DAL        128.00
# 367         Michael Carter     68  200.00       0.00        NYJ        107.00
# 215         Saquon Barkley     72  233.00       3.00        NYG          2.00
# 58         Devonta Freeman     68  206.00       7.00        ATL        103.00
# 216            Sony Michel     71  215.00       3.00         NE         31.00
# 201          Chase Edmonds     69  210.00       3.00        ARI        134.00
# 328    22.00       RB                   RB          23.00           513
# 346    23.00       RB                   RB          32.00           516
# 308    23.00       RB                   RB          32.00           517
# 303    23.00       RB                   RB          22.00           528
# 812    25.00       RB                   RB          48.00           531
# 315    22.00       RB                   RB          26.00           537
# 338    23.00       RB                   RB          37.00           540
# 211    24.00       RB                   RB          41.00           554
# 357    23.00       RB                   RB          34.00           573
# 171    27.00       RB                   RB          49.00           574
# 40     32.00       RB                   RB          38.00           582
#
#      rush_rank  rec_rank  pass_rank  position_rank  \
# 295          1       120         90              1
# 361          7        65         90              2
# 154          2       114         90              3
# 137          5       112         90              4
# 144         14        78         90              5
# 113          8       123         87              6
# 155         19        85         90              7
# 47          26        67         90              8
# 272         12       119         90              9
# 313         13       117         90             10
# 125         24        76         90             11
# 305         28        80         90             12
# 207          4       229         90             13
# 266          3       266         90             14
# 79          11       186         90             15
# 379         20       110         90             16
# 152         10       197         90             17
# 239         15       168         90             18
# 271         17       159         90             19
# 97           9       259         67             20
# 301         22       146         90             21
# 247         39       104         90             22
# 337         16       245         90             23
# 269         25       180         90             24
# 240         35       157         90             25
# 367         31       170         90             26
# 215         46       139         90             27
# 58          32       190         90             28
# 216         23       240         90             29
# 201         45       153         90             30
# 107         44       156         90             31
# 75          48       150         90             32
# 336         30       215         90             33
# 122         61       147         90             34
# 222         50       187         90             35
# 203         21       351         90             36
# 366         56       182         90             37
# 162         37       235         90             38
# 259         74       129         90             39
# 358         29       279         90             40
# 183         67       149         90             41
# 320         42       226         90             42
# 238         40       234         90             43
# 20          49       231         90             44
# 159         47       243         90             45
# 297         55       212         90             46
# 37          52       228         90             47
# 43          33       316         90             48
# 117         72       177         90             49
# 187         38       296         90             50
# 160         41       296         90             51
# 76         104       155         90             52
# 191         64       239         90             53
# 134         78       205         90             54
# 81          94       188         90             55
# 212         51       323         90             56
# 364         58       288         90             57
# 31         144       175         90             58
# 165        110       191         90             59
# 90          59       313         90             60
# 98          54       423         90             61
# 330         88       255         90             62
# 86          60       376         90             63
# 39         163       201         90             64
# 261         89       265         90             65
# 73          73       327         90             66
# 345        198       217         90             67
# 356        147       233         90             68
# 139         68       366         90             69
# 51          86       309         90             70
# 332         81       388         90             71
# 41          92       338         90             72
# 60         157       272         90             73
# 214        103       315         90             74
# 52         133       295         90             75
# 376         91       401         90             76
# 324        101       356         90             77
# 4           93       409         90             78
# 347         96       394         90             79
# 108        119       386         90             80
# 242        116       404         90             81
# 322        143       368         90             82
# 344        115       458         90             83
# 66         142       398         90             84
# 163        129       431         90             85
# 236        132       429         90             86
# 164        131       438         90             87
# 241        146       412         90             88
# 354        159       407         90             89
# 106        161       424         90             90
# 126        205       385         90             91
# 99         196       396         90             92
# 245        166       454         90             93
# 210        180       438         90             94
# 184        155       462         90             95
# 181        234       417         90             96
# 306        165       462         90             97
# 92         214       430         90             98
# 103        257       415         90             99
# 328        253       421         90            100
# 346        200       453         90            101
# 308        238       432         90            102
# 303        192       462         90            103
# 812        258       435         90            104
# 315        252       447         90            105
# 338        250       452         90            106
# 211        223       462         90            107
# 357        244       462         90            108
# 171        249       462         90            109
# 40         258       462         90            110
#
#      fantasy_total_pts_nextYear  fantasy_total_pts_nextYearDiff
# 295                       95.60                          277.50
# 361                       99.76                          200.94
# 154                      171.70                          122.20
# 137                       85.30                          171.50
# 144                      156.70                           98.90
# 113                       77.50                          167.16
# 155                      141.70                           93.00
# 47                        80.10                          153.70
# 272                      175.10                           56.90
# 313                      126.50                          102.60
# 125                      160.60                           68.40
# 305                       81.30                          135.40
# 207                      176.20                           39.10
# 266                       63.90                          146.20
# 79                        81.10                          126.00
# 379                       42.00                          162.90
# 152                      149.30                           55.00
# 239                      102.10                           95.70
# 271                       91.40                          105.30
# 97                       177.70                           13.60
# 301                       77.30                          108.30
# 247                        6.30                          167.30
# 337                       13.90                          151.10
# 269                       72.60                           90.80
# 240                      126.50                           30.10
# 367                       95.60                           59.00
# 215                      177.80                          -29.20
# 58                          NaN                             NaN
# 216                       24.80                          121.50
# 201                       51.50                           93.80
# 107                         NaN                             NaN
# 75                         3.50                          138.70
# 336                       21.20                          116.40
# 122                      184.16                          -56.66
# 222                       49.50                           76.40
# 203                       52.20                           69.50
# 366                       44.90                           76.50
# 162                      127.10                           -7.30
# 259                        5.60                          111.40
# 358                      149.50                          -32.60
# 183                       55.30                           60.30
# 320                       97.40                           18.20
# 238                      122.20                           -7.00
# 20                        39.20                           69.40
# 159                       88.10                           19.70
# 297                       17.20                           90.00
# 37                        57.20                           47.10
# 43                        51.80                           51.80
# 117                       71.90                           30.60
# 187                       14.80                           83.80
# 160                       73.10                           20.80
# 76                        21.90                           67.60
# 191                       17.80                           68.40
# 134                       49.90                           33.30
# 81                          NaN                             NaN
# 212                         NaN                             NaN
# 364                      106.50                          -27.60
# 31                        33.30                           40.50
# 165                         NaN                             NaN
# 90                          NaN                             NaN
# 98                         0.10                           62.40
# 330                       14.40                           45.70
# 86                         0.40                           58.70
# 39                          NaN                             NaN
# 261                       19.40                           36.40
# 73                        22.00                           29.50
# 345                        0.90                           49.60
# 356                        5.00                           44.80
# 139                         NaN                             NaN
# 51                          NaN                             NaN
# 332                        2.70                           33.90
# 41                          NaN                             NaN
# 60                        64.70                          -29.70
# 214                         NaN                             NaN
# 52                          NaN                             NaN
# 376                        1.90                           26.40
# 324                       84.30                          -56.30
# 4                           NaN                             NaN
# 347                         NaN                             NaN
# 108                        5.40                           15.30
# 242                         NaN                             NaN
# 322                       29.00                          -12.00
# 344                         NaN                             NaN
# 66                         3.80                           10.90
# 163                         NaN                             NaN
# 236                         NaN                             NaN
# 164                         NaN                             NaN
# 241                         NaN                             NaN
# 354                         NaN                             NaN
# 106                         NaN                             NaN
# 126                         NaN                             NaN
# 99                          NaN                             NaN
# 245                         NaN                             NaN
# 210                         NaN                             NaN
# 184                         NaN                             NaN
# 181                         NaN                             NaN
# 306                         NaN                             NaN
# 92                         5.50                           -0.70
# 103                       10.40                           -5.80
# 328                       25.40                          -21.10
# 346                        0.70                            3.20
# 308                         NaN                             NaN
# 303                         NaN                             NaN
# 812                         NaN                             NaN
# 315                         NaN                             NaN
# 338                        7.90                           -5.90
# 211                         NaN                             NaN
# 357                         NaN                             NaN
# 171                         NaN                             NaN
# 40                          NaN                             NaN

# %%
# Set plot parameters
plot_position = 'WR'
plot_x = 'position_rank'
plot_y = 'fantasy_total_pts_nextYear'
plot_min_x = 0
plot_max_x = 40
bin_step = 5

binning = True

#=================================================

if binning==True:
    plot_df = column_binner(
        off_agg_df[
            (off_agg_df['position'] == plot_position)& \
            (off_agg_df[plot_x] <= plot_max_x)
        ], 
        plot_x, plot_min_x, plot_max_x, bin_step
    )
    plot_x = plot_x + '_binned'
else:
    plot_df = off_agg_df[(off_agg_df['position']==plot_position)&(off_agg_df[plot_x]<=plot_max_x)]
    
sns.set(rc={'figure.figsize':(12,9)})
plot = sns.barplot(
    data=plot_df, 
    x=plot_x, 
    y=plot_y,
    color='grey'
)

# %%
# plot_position = 'WR'
# plot_max_rank = 40
# g = sns.FacetGrid(off_agg_df[(off_agg_df['position_rank']<=plot_max_rank)], 
#                   col="position_rank",
#                   row="fantasy_total_pts_nextYearDiff",
#                   hue="position")
# g.map(sns.lineplot, "position_rank")

# %%
# # Apply custom pivot
# values = ['fantasy_total_pts','overall_rank','position_rank','rush_rank','rec_rank','pass_rank']
# columns = ['season']
# index = ['player_id','player_name','first_name','last_name','position']
# off_agg_pivot_df = custom_pivot(off_agg_df, values, columns, index)
# off_agg_pivot_df

# for column in off_agg_pivot_df.columns:
#     if column[0:1].isdigit():
#         for sub_column in off_agg_pivot_df.columns:
#             if sub_column[0:1].isdigit():
#                 if (column[5:]==sub_column[5:])&(int(column[:4])==(int(sub_column[:4])+1)):
#                     new_col = column + '_prevDiff'
#                     off_agg_pivot_df[new_col] = off_agg_pivot_df[column] - off_agg_pivot_df[sub_column]
#                 elif (column[5:]==sub_column[5:])&((int(column[:4])+1)==int(sub_column[:4])):
#                     new_col = column + '_nextDiff'
#                     off_agg_pivot_df[new_col] = off_agg_pivot_df[column] - off_agg_pivot_df[sub_column]
#                 else: pass
#             else: pass
#     else: pass

# off_agg_melt_df = off_agg_pivot_df.melt(id_vars=index, var_name='variable')
# off_agg_filter_df = off_agg_melt_df[off_agg_melt_df['variable'].str.contains('position_rank', na=False) |
#                                     off_agg_melt_df['variable'].str.contains('pts_nextDiff', na=False) |
#                                     off_agg_melt_df['variable'].str.contains('position_rank_nextDiff', na=False)]
# off_agg_filter_df['new_variable'] = off_agg_filter_df['variable'].str[5:]
# off_agg_repivot_df = pd.pivot_table(off_agg_filter_df, values=['value'], columns=['new_variable'], index=index)
# off_agg_repivot_df = off_agg_repivot_df['value'].reset_index()
# off_agg_repivot_df

# %% [markdown]
# <h2>Data Exploration</h2>

# %%
nfl.import_ngs_data(stat_type='rushing', years=env_dict['seasons'])

# %%
nfl.import_draft_picks([2021])

# %%
nfl.import_officials([2020])

# %%
nfl.import_draft_values()
