# %% [markdown]
# # Fantasy Football Draft Guide

# %%
# Import libraries
from utils import *
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from warnings import simplefilter
from datetime import *

# Configure Pandas settings
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# Set pbp data read option
read_local_data = False

# %% [markdown]
# ## Data Imports

# %%
# Set filepath for config yaml
filepath = "fantasy_config.yml"

# Read yaml and flatten
env_dict = flatten_dict(read_yaml(filepath))
env_dict
# Out:
# {'seasons': [2022, 2021],
#  'rec_rec': 1,
#  'rec_td': 6,
#  'rec_yd': 0.1,
#  'rec_twoPointConv': 2,
#  'rush_td': 6,
#  'rush_yd': 0.1,
#  'rush_lostFumble': -2,
#  'rush_twoPointConv': 2,
#  'pass_td': 4,
#  'pass_yd': 0.04,
#  'pass_int': -1,
#  'pass_twoPointConv': 2,
#  'kick_fg_00_19': 3,
#  'kick_fg_20_29': 3,
#  'kick_fg_30_39': 3,
#  'kick_fg_40_49': 4,
#  'kick_fg_50_xx': 5,
#  'kick_fg_miss': -1,
#  'kick_pat_make': 1,
#  'kick_pat_miss': -1,
#  'def_td': 6,
#  'def_sack': 1,
#  'def_int': 2,
#  'def_forceFum': 1,
#  'def_recovFum': 2,
#  'def_recovFumTD': 6,
#  'def_safety': 2,
#  'def_allow_00_00': 10,
#  'def_allow_01_06': 7,
#  'def_allow_07_13': 4,
#  'def_allow_14_20': 1,
#  'def_allow_21_27': 0,
#  'def_allow_28_34': -1,
#  'def_allow_35_xx': -4,
#  'spec_td': 6,
#  'spec_recovFumTD': 6,
#  'spec_blockKick': 2,
#  'spec_forceFum': 1,
#  'spec_recovFum': 1}

# %%
pbp_enrich_df = import_enrich_pbp_data(years=env_dict['seasons'], regular=True)
# Out:
# 2022 done.
# 2021 done.
# Downcasting floats.
# Adding participation data.
# Adding fantasy data.

# %%
pbp_enrich_df['play_type_nfl'].unique()
# Out:
# array(['GAME_START', 'KICK_OFF', 'RUSH', 'PASS', 'PUNT', 'TIMEOUT',
#        'PENALTY', 'FIELD_GOAL', 'END_QUARTER', 'SACK', 'XP_KICK',
#        'END_GAME', 'PAT2', None, 'FREE_KICK', 'COMMENT'], dtype=object)

# %%
pbp_enrich_df[pbp_enrich_df['play_type_nfl'].isnull()]
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 2708   4040.00   2022_01_SF_CHI    2022091102       CHI        SF         REG
# 6446   1669.00  2022_03_DAL_NYG    2022092600       NYG       DAL         REG
# 20043  3445.00  2022_08_CIN_CLE    2022103100       CLE       CIN         REG
# 24234  1128.00  2022_10_ATL_CAR    2022111000       CAR       ATL         REG
# 26869  4092.00  2021_01_ARI_TEN    2021091207       TEN       ARI         REG
# 37245   471.00   2021_04_PIT_GB    2021100312        GB       PIT         REG
# 39195  2506.00   2021_05_GB_CIN    2021101002       CIN        GB         REG
# 52056  2644.00  2021_10_DET_PIT    2021111404       PIT       DET         REG
# 53715  4250.00  2021_11_ARI_SEA    2021112111       SEA       ARI         REG
# 62261    54.00  2021_14_DET_DEN    2021121208       DEN       DET         REG
# 67238  3578.00  2021_16_CHI_SEA    2021122608       SEA       CHI         REG
#
#        week posteam posteam_type defteam side_of_field  yardline_100  \
# 2708      1     CHI         home      SF            SF         45.00
# 6446      3     DAL         away     NYG           NYG         40.00
# 20043     8     CLE         home     CIN           CIN         40.00
# 24234    10     CAR         home     ATL           ATL         35.00
# 26869     1     ARI         away     TEN           TEN         41.00
# 37245     4      GB         home     PIT           PIT         40.00
# 39195     5     CIN         home      GB            GB         40.00
# 52056    10     DET         away     PIT           PIT         39.00
# 53715    11     ARI         away     SEA           SEA         33.00
# 62261    14     DEN         home     DET           DEN         75.00
# 67238    16     SEA         home     CHI           CHI         41.00
#
#         game_date  quarter_seconds_remaining  half_seconds_remaining  \
# 2708   2022-09-11                     157.00                  157.00
# 6446   2022-09-26                     158.00                  158.00
# 20043  2022-10-31                     343.00                  343.00
# 24234  2022-11-10                     488.00                  488.00
# 26869  2021-09-12                     127.00                  127.00
# 37245  2021-10-03                     273.00                 1173.00
# 39195  2021-10-10                      27.00                  927.00
# 52056  2021-11-14                     292.00                 1192.00
# 53715  2021-11-21                      24.00                   24.00
# 62261  2021-12-12                     900.00                 1800.00
# 67238  2021-12-26                     183.00                  183.00
#
#        game_seconds_remaining game_half  quarter_end  drive   sp  qtr  down  \
# 2708                   157.00     Half2         0.00  20.00 0.00 4.00  4.00
# 6446                  1958.00     Half1         0.00   7.00 0.00 2.00  4.00
# 20043                  343.00     Half2         0.00  19.00 0.00 4.00  4.00
# 24234                 2288.00     Half1         0.00   4.00 0.00 2.00  4.00
# 26869                  127.00     Half2         0.00  23.00 0.00 4.00  4.00
# 37245                 2973.00     Half1         0.00   2.00 0.00 1.00  4.00
# 39195                  927.00     Half2         0.00  16.00 0.00 3.00  4.00
# 52056                 1192.00     Half2         0.00  13.00 0.00 3.00  4.00
# 53715                   24.00     Half2         0.00  19.00 0.00 4.00  4.00
# 62261                 3600.00     Half1         0.00   1.00 0.00 1.00  1.00
# 67238                  183.00     Half2         0.00  18.00 0.00 4.00  4.00
#
#        goal_to_go   time   yrdln  ydstogo  ydsnet  \
# 2708         0.00  02:37   SF 45    10.00    0.00
# 6446         0.00  02:38  NYG 40    10.00   37.00
# 20043        0.00  05:43  CIN 40     5.00    5.00
# 24234        0.00  08:08  ATL 35    19.00   56.00
# 26869        0.00  02:07  TEN 41     7.00   25.00
# 37245        0.00  04:33  PIT 40     9.00   38.00
# 39195        0.00  00:27   GB 40    12.00   35.00
# 52056        0.00  04:52  PIT 39     5.00   28.00
# 53715        0.00  00:24  SEA 33    10.00    0.00
# 62261        0.00  15:00  DEN 25    10.00   75.00
# 67238        0.00  03:03  CHI 41    21.00    5.00
#
#                                                                    desc  \
# 2708          (2:37) (Shotgun) Penalty on CHI, Delay of Game, declined.
# 6446   (2:38) (Punt formation) Penalty on DAL, Delay of Game, declined.
# 20043   (5:43) (Run formation) Penalty on CLE, Delay of Game, declined.
# 24234  (8:08) (Punt formation) Penalty on CAR, Delay of Game, declined.
# 26869  (2:07) (Punt formation) Penalty on ARI, Delay of Game, declined.
# 37245   (4:33) (Punt formation) Penalty on GB, Delay of Game, declined.
# 39195          (:27) (Shotgun) Penalty on CIN, Delay of Game, declined.
# 52056         (4:52) (Shotgun) Penalty on DET, Delay of Game, declined.
# 53715   (:24) (Punt formation) Penalty on ARI, Delay of Game, declined.
# 62261        (15:00) (Shotgun) Penalty on DEN, Delay of Game, declined.
# 67238  (3:03) (Punt formation) Penalty on SEA, Delay of Game, declined.
#
#       play_type  yards_gained  shotgun  no_huddle  qb_dropback  qb_kneel  \
# 2708       None           NaN     1.00       0.00          NaN      0.00
# 6446       None           NaN     0.00       0.00          NaN      0.00
# 20043      None           NaN     0.00       0.00          NaN      0.00
# 24234      None           NaN     0.00       0.00          NaN      0.00
# 26869      None           NaN     0.00       0.00          NaN      0.00
# 37245      None           NaN     0.00       0.00          NaN      0.00
# 39195      None           NaN     1.00       0.00          NaN      0.00
# 52056      None           NaN     1.00       0.00          NaN      0.00
# 53715      None           NaN     0.00       0.00          NaN      0.00
# 62261      None           NaN     1.00       0.00          NaN      0.00
# 67238      None           NaN     0.00       0.00          NaN      0.00
#
#        qb_spike  qb_scramble pass_length pass_location  air_yards  \
# 2708       0.00         0.00        None          None        NaN
# 6446       0.00         0.00        None          None        NaN
# 20043      0.00         0.00        None          None        NaN
# 24234      0.00         0.00        None          None        NaN
# 26869      0.00         0.00        None          None        NaN
# 37245      0.00         0.00        None          None        NaN
# 39195      0.00         0.00        None          None        NaN
# 52056      0.00         0.00        None          None        NaN
# 53715      0.00         0.00        None          None        NaN
# 62261      0.00         0.00        None          None        NaN
# 67238      0.00         0.00        None          None        NaN
#
#        yards_after_catch run_location run_gap field_goal_result  \
# 2708                 NaN         None    None              None
# 6446                 NaN         None    None              None
# 20043                NaN         None    None              None
# 24234                NaN         None    None              None
# 26869                NaN         None    None              None
# 37245                NaN         None    None              None
# 39195                NaN         None    None              None
# 52056                NaN         None    None              None
# 53715                NaN         None    None              None
# 62261                NaN         None    None              None
# 67238                NaN         None    None              None
#
#        kick_distance extra_point_result two_point_conv_result  \
# 2708             NaN               None                  None
# 6446             NaN               None                  None
# 20043            NaN               None                  None
# 24234            NaN               None                  None
# 26869            NaN               None                  None
# 37245            NaN               None                  None
# 39195            NaN               None                  None
# 52056            NaN               None                  None
# 53715            NaN               None                  None
# 62261            NaN               None                  None
# 67238            NaN               None                  None
#
#        home_timeouts_remaining  away_timeouts_remaining  timeout timeout_team  \
# 2708                      3.00                     0.00      NaN         None
# 6446                      3.00                     3.00      NaN         None
# 20043                     3.00                     1.00      NaN         None
# 24234                     2.00                     3.00      NaN         None
# 26869                     3.00                     0.00      NaN         None
# 37245                     3.00                     3.00      NaN         None
# 39195                     3.00                     3.00      NaN         None
# 52056                     3.00                     3.00      NaN         None
# 53715                     0.00                     0.00      NaN         None
# 62261                     3.00                     3.00      NaN         None
# 67238                     2.00                     2.00      NaN         None
# 53715     0.00              0.00                       0.00  1.11 -0.00
# 62261     0.00              0.00                       0.00  1.47  0.00
# 67238     0.00              0.00                       0.00  0.16  0.00
#
#        total_home_epa  total_away_epa  total_home_rush_epa  \
# 2708             7.99           -7.99                -0.07
# 6446            -4.10            4.10                -7.51
# 20043           20.73          -20.73                 4.56
# 24234            5.57           -5.57                 5.67
# 26869          -33.28           33.28                -4.85
# 37245           -7.37            7.37                -1.24
# 39195           -9.01            9.01                -2.72
# 52056           -4.03            4.03                -3.61
# 53715          -13.99           13.99                 1.11
# 62261            0.00            0.00                 0.00
# 67238            4.89           -4.89                 6.80
#
#        total_away_rush_epa  total_home_pass_epa  total_away_pass_epa  air_epa  \
# 2708                  0.07                 4.55                -4.55      NaN
# 6446                  7.51                 1.83                -1.83      NaN
# 20043                -4.56                14.15               -14.15      NaN
# 24234                -5.67                -2.17                 2.17      NaN
# 26869                 4.85               -28.45                28.45      NaN
# 37245                 1.24                -5.59                 5.59      NaN
# 39195                 2.72                -3.62                 3.62      NaN
# 52056                 3.61                -2.08                 2.08      NaN
# 53715                -1.11               -20.64                20.64      NaN
# 62261                 0.00                 0.00                 0.00      NaN
# 67238                -6.80                 5.19                -5.19      NaN
#
#        yac_epa  comp_air_epa  comp_yac_epa  total_home_comp_air_epa  \
# 2708       NaN           NaN           NaN                    -5.37
# 6446       NaN           NaN           NaN                    -1.99
# 20043      NaN           NaN           NaN                    12.72
# 24234      NaN           NaN           NaN                    -5.73
# 26869      NaN           NaN           NaN                    -5.60
# 37245      NaN           NaN           NaN                    -1.40
# 39195      NaN           NaN           NaN                    -3.03
# 52056      NaN           NaN           NaN                     6.60
# 53715      NaN           NaN           NaN                     4.29
# 62261      NaN           NaN           NaN                     0.00
# 67238      NaN           NaN           NaN                     8.14
#
#        total_away_comp_air_epa  total_home_comp_yac_epa  \
# 2708                      5.37                     3.65
# 6446                      1.99                     5.50
# 20043                   -12.72                    -8.45
# 24234                     5.73                     4.75
# 26869                     5.60                    -1.60
# 37245                     1.40                    -1.50
# 39195                     3.03                     2.33
# 52056                    -6.60                     0.99
# 53715                    -4.29                   -17.24
# 62261                     0.00                     0.00
# 67238                    -8.14                    -7.39
#
#        total_away_comp_yac_epa  total_home_raw_air_epa  \
# 2708                     -3.65                    1.60
# 6446                     -5.50                    5.46
# 20043                     8.45                   13.94
# 24234                    -4.75                   -7.22
# 26869                     1.60                   -5.50
# 37245                     1.50                   -1.40
# 39195                    -2.33                   -5.79
# 52056                    -0.99                   15.98
# 53715                    17.24                   15.47
# 62261                     0.00                    0.00
# 67238                     7.39                   12.75
#
#        total_away_raw_air_epa  total_home_raw_yac_epa  total_away_raw_yac_epa  \
# 2708                    -1.60                    3.82                   -3.82
# 6446                    -5.46                   -1.64                    1.64
# 20043                  -13.94                   -6.03                    6.03
# 24234                    7.22                    6.72                   -6.72
# 26869                    5.50                   -5.12                    5.12
# 37245                    1.40                   -1.50                    1.50
# 39195                    5.79                    6.70                   -6.70
# 52056                  -15.98                  -18.06                   18.06
# 53715                  -15.47                  -32.38                   32.38
# 62261                    0.00                    0.00                    0.00
# 67238                  -12.75                   -8.05                    8.05
#
#         wp  def_wp  home_wp  away_wp   wpa  vegas_wpa  vegas_home_wpa  \
# 2708  0.97    0.03     0.97     0.03  0.00       0.00            0.00
# 6446  0.56    0.44     0.44     0.56 -0.00      -0.00            0.00
# 20043 1.00    0.00     1.00     0.00  0.00       0.00            0.00
# 24234 0.70    0.30     0.70     0.30  0.00       0.00            0.00
# 26869 1.00    0.00     0.00     1.00 -0.00      -0.00            0.00
# 37245 0.37    0.63     0.37     0.63  0.00       0.00            0.00
# 39195 0.29    0.71     0.29     0.71  0.00      -0.00           -0.00
# 52056 0.65    0.35     0.35     0.65 -0.00       0.01           -0.01
# 53715 1.00    0.00     0.00     1.00 -0.00      -0.00            0.00
# 62261 0.55    0.45     0.55     0.45  0.00       0.00            0.00
# 67238 0.90    0.10     0.90     0.10  0.00       0.00            0.00
#
#        home_wp_post  away_wp_post  vegas_wp  vegas_home_wp  \
# 2708           0.97          0.03      0.97           0.97
# 6446           0.44          0.56      0.60           0.40
# 20043           NaN           NaN      1.00           1.00
# 24234          0.70          0.30      0.57           0.57
# 26869          0.00          1.00      1.00           0.00
# 37245          0.37          0.63      0.58           0.58
# 39195           NaN           NaN      0.27           0.27
# 52056          0.35          0.65      0.50           0.50
# 53715          0.00          1.00      1.00           0.00
# 62261          0.55          0.45      0.89           0.89
# 67238          0.90          0.10      0.93           0.93
#
#        total_home_rush_wpa  total_away_rush_wpa  total_home_pass_wpa  \
# 2708                  0.14                -0.14                 0.04
# 6446                 -0.21                 0.21                 0.03
# 20043                 0.16                -0.16                 0.38
# 24234                 0.15                -0.15                -0.06
# 26869                -0.15                 0.15                -0.43
# 37245                -0.03                 0.03                -0.17
# 39195                -0.04                 0.04                -0.10
# 52056                -0.24                 0.24                -0.07
# 53715                -0.06                 0.06                -0.51
# 62261                 0.00                 0.00                 0.00
# 67238                 0.25                -0.25                 0.10
#
#        total_away_pass_wpa  air_wpa  yac_wpa  comp_air_wpa  comp_yac_wpa  \
# 2708                 -0.04      NaN      NaN           NaN           NaN
# 6446                 -0.03      NaN      NaN           NaN           NaN
# 20043                -0.38      NaN      NaN           NaN           NaN
# 24234                 0.06      NaN      NaN           NaN           NaN
# 26869                 0.43      NaN      NaN           NaN           NaN
# 37245                 0.17      NaN      NaN           NaN           NaN
# 39195                 0.10      NaN      NaN           NaN           NaN
# 52056                 0.07      NaN      NaN           NaN           NaN
# 53715                 0.51      NaN      NaN           NaN           NaN
# 62261                 0.00      NaN      NaN           NaN           NaN
# 67238                -0.10      NaN      NaN           NaN           NaN
#
#        total_home_comp_air_wpa  total_away_comp_air_wpa  \
# 2708                     -0.02                     0.02
# 6446                      0.05                    -0.05
# 20043                    -0.02                     0.02
# 24234                     0.04                    -0.04
# 26869                     0.76                    -0.76
# 37245                     0.00                    -0.00
# 39195                    -0.09                     0.09
# 52056                     0.12                    -0.12
# 53715                    -0.25                     0.25
# 62261                     0.00                     0.00
# 67238                    -0.10                     0.10
#
#        total_home_comp_yac_wpa  total_away_comp_yac_wpa  \
# 2708                     -0.01                     0.01
# 6446                     -0.01                     0.01
# 20043                     0.22                    -0.22
# 24234                    -0.09                     0.09
# 26869                    -1.04                     1.04
# 37245                    -0.10                     0.10
# 39195                     0.11                    -0.11
# 52056                     0.02                    -0.02
# 53715                    -0.11                     0.11
# 62261                     0.00                     0.00
# 67238                     0.10                    -0.10
#
#        total_home_raw_air_wpa  total_away_raw_air_wpa  total_home_raw_yac_wpa  \
# 2708                     0.02                   -0.02                    0.06
# 6446                     0.05                   -0.05                    0.04
# 20043                   -0.02                    0.02                    0.26
# 24234                    0.04                   -0.04                   -0.07
# 26869                    0.76                   -0.76                   -1.04
# 37245                    0.00                   -0.00                   -0.10
# 39195                   -0.09                    0.09                    0.09
# 52056                    0.11                   -0.11                   -0.18
# 53715                   -0.24                    0.24                   -0.20
# 62261                    0.00                    0.00                    0.00
# 67238                   -0.10                    0.10                    0.20
#
#        total_away_raw_yac_wpa  punt_blocked  first_down_rush  first_down_pass  \
# 2708                    -0.06           NaN              NaN              NaN
# 6446                    -0.04           NaN              NaN              NaN
# 20043                   -0.26           NaN              NaN              NaN
# 24234                    0.07           NaN              NaN              NaN
# 26869                    1.04           NaN              NaN              NaN
# 37245                    0.10           NaN              NaN              NaN
# 39195                   -0.09           NaN              NaN              NaN
# 52056                    0.18           NaN              NaN              NaN
# 53715                    0.20           NaN              NaN              NaN
# 62261                    0.00           NaN              NaN              NaN
# 67238                   -0.20           NaN              NaN              NaN
#
#        first_down_penalty  third_down_converted  third_down_failed  \
# 2708                  NaN                   NaN                NaN
# 6446                  NaN                   NaN                NaN
# 20043                 NaN                   NaN                NaN
# 24234                 NaN                   NaN                NaN
# 26869                 NaN                   NaN                NaN
# 37245                 NaN                   NaN                NaN
# 39195                 NaN                   NaN                NaN
# 52056                 NaN                   NaN                NaN
# 53715                 NaN                   NaN                NaN
# 62261                 NaN                   NaN                NaN
# 67238                 NaN                   NaN                NaN
#
#        fourth_down_converted  fourth_down_failed  incomplete_pass  touchback  \
# 2708                     NaN                 NaN              NaN       0.00
# 6446                     NaN                 NaN              NaN       0.00
# 20043                    NaN                 NaN              NaN       0.00
# 24234                    NaN                 NaN              NaN       0.00
# 26869                    NaN                 NaN              NaN       0.00
# 37245                    NaN                 NaN              NaN       0.00
# 39195                    NaN                 NaN              NaN       0.00
# 52056                    NaN                 NaN              NaN       0.00
# 53715                    NaN                 NaN              NaN       0.00
# 62261                    NaN                 NaN              NaN       0.00
# 67238                    NaN                 NaN              NaN       0.00
#
#        interception  punt_inside_twenty  punt_in_endzone  punt_out_of_bounds  \
# 2708            NaN                 NaN              NaN                 NaN
# 6446            NaN                 NaN              NaN                 NaN
# 20043           NaN                 NaN              NaN                 NaN
# 24234           NaN                 NaN              NaN                 NaN
# 26869           NaN                 NaN              NaN                 NaN
# 62261            NaN               None                 None              NaN
# 67238            NaN               None                 None              NaN
#
#       rusher_player_id rusher_player_name  rushing_yards  \
# 2708              None               None            NaN
# 6446              None               None            NaN
# 20043             None               None            NaN
# 24234             None               None            NaN
# 26869             None               None            NaN
# 37245             None               None            NaN
# 39195             None               None            NaN
# 52056             None               None            NaN
# 53715             None               None            NaN
# 62261             None               None            NaN
# 67238             None               None            NaN
#
#       lateral_receiver_player_id lateral_receiver_player_name  \
# 2708                        None                         None
# 6446                        None                         None
# 20043                       None                         None
# 24234                       None                         None
# 26869                       None                         None
# 37245                       None                         None
# 39195                       None                         None
# 52056                       None                         None
# 53715                       None                         None
# 62261                       None                         None
# 67238                       None                         None
#
#        lateral_receiving_yards lateral_rusher_player_id  \
# 2708                       NaN                     None
# 6446                       NaN                     None
# 20043                      NaN                     None
# 24234                      NaN                     None
# 26869                      NaN                     None
# 37245                      NaN                     None
# 39195                      NaN                     None
# 52056                      NaN                     None
# 53715                      NaN                     None
# 62261                      NaN                     None
# 67238                      NaN                     None
#
#       lateral_rusher_player_name  lateral_rushing_yards  \
# 2708                        None                    NaN
# 6446                        None                    NaN
# 20043                       None                    NaN
# 24234                       None                    NaN
# 26869                       None                    NaN
# 37245                       None                    NaN
# 39195                       None                    NaN
# 52056                       None                    NaN
# 53715                       None                    NaN
# 62261                       None                    NaN
# 67238                       None                    NaN
#
#       lateral_sack_player_id lateral_sack_player_name interception_player_id  \
# 2708                    None                     None                   None
# 6446                    None                     None                   None
# 20043                   None                     None                   None
# 24234                   None                     None                   None
# 26869                   None                     None                   None
# 37245                   None                     None                   None
# 39195                   None                     None                   None
# 52056                   None                     None                   None
# 53715                   None                     None                   None
# 62261                   None                     None                   None
# 67238                   None                     None                   None
#
#       interception_player_name lateral_interception_player_id  \
# 2708                      None                           None
# 6446                      None                           None
# 20043                     None                           None
# 24234                     None                           None
# 26869                     None                           None
# 37245                     None                           None
# 39195                     None                           None
# 52056                     None                           None
# 53715                     None                           None
# 62261                     None                           None
# 67238                     None                           None
#
#       lateral_interception_player_name punt_returner_player_id  \
# 2708                              None                    None
# 6446                              None                    None
# 20043                             None                    None
# 24234                             None                    None
# 26869                             None                    None
# 37245                             None                    None
# 39195                             None                    None
# 52056                             None                    None
# 53715                             None                    None
# 62261                             None                    None
# 67238                             None                    None
#
#       punt_returner_player_name lateral_punt_returner_player_id  \
# 2708                       None                            None
# 6446                       None                            None
# 20043                      None                            None
# 24234                      None                            None
# 26869                      None                            None
# 37245                      None                            None
# 39195                      None                            None
# 52056                      None                            None
# 53715                      None                            None
# 62261                      None                            None
# 67238                      None                            None
#
#       lateral_punt_returner_player_name kickoff_returner_player_name  \
# 2708                               None                         None
# 6446                               None                         None
# 20043                              None                         None
# 24234                              None                         None
# 26869                              None                         None
# 37245                              None                         None
# 39195                              None                         None
# 52056                              None                         None
# 53715                              None                         None
# 62261                              None                         None
# 67238                              None                         None
#
#       kickoff_returner_player_id lateral_kickoff_returner_player_id  \
# 2708                        None                               None
# 6446                        None                               None
# 20043                       None                               None
# 24234                       None                               None
# 26869                       None                               None
# 37245                       None                               None
# 39195                       None                               None
# 52056                       None                               None
# 53715                       None                               None
# 62261                       None                               None
# 67238                       None                               None
#
#       lateral_kickoff_returner_player_name punter_player_id  \
# 2708                                  None             None
# 6446                                  None             None
# 20043                                 None             None
# 24234                                 None             None
# 26869                                 None             None
# 37245                                 None             None
# 39195                                 None             None
# 52056                                 None             None
# 53715                                 None             None
# 62261                                 None             None
# 67238                                 None             None
#
#       punter_player_name kicker_player_name kicker_player_id  \
# 2708                None               None             None
# 6446                None               None             None
# 20043               None               None             None
# 24234               None               None             None
# ...
# 67238                   NaN   None                   NaN     None
#
#        receiver_jersey_number  pass  rush  first_down  special  play  \
# 2708                      NaN  0.00  0.00         NaN     0.00  0.00
# 6446                      NaN  0.00  0.00         NaN     0.00  0.00
# 20043                     NaN  0.00  0.00         NaN     0.00  0.00
# 24234                     NaN  0.00  0.00         NaN     0.00  0.00
# 26869                     NaN  0.00  0.00         NaN     0.00  0.00
# 37245                     NaN  0.00  0.00         NaN     0.00  0.00
# 39195                     NaN  0.00  0.00         NaN     0.00  0.00
# 52056                     NaN  0.00  0.00         NaN     0.00  0.00
# 53715                     NaN  0.00  0.00         NaN     0.00  0.00
# 62261                     NaN  0.00  0.00         NaN     0.00  0.00
# 67238                     NaN  0.00  0.00         NaN     0.00  0.00
#
#       passer_id rusher_id receiver_id  name  jersey_number    id  \
# 2708       None      None        None  None            NaN  None
# 6446       None      None        None  None            NaN  None
# 20043      None      None        None  None            NaN  None
# 24234      None      None        None  None            NaN  None
# 26869      None      None        None  None            NaN  None
# 37245      None      None        None  None            NaN  None
# 39195      None      None        None  None            NaN  None
# 52056      None      None        None  None            NaN  None
# 53715      None      None        None  None            NaN  None
# 62261      None      None        None  None            NaN  None
# 67238      None      None        None  None            NaN  None
#
#       fantasy_player_name fantasy_player_id fantasy fantasy_id  out_of_bounds  \
# 2708                 None              None    None       None           0.00
# 6446                 None              None    None       None           0.00
# 20043                None              None    None       None           0.00
# 24234                None              None    None       None           0.00
# 26869                None              None    None       None           0.00
# 37245                None              None    None       None           0.00
# 39195                None              None    None       None           0.00
# 52056                None              None    None       None           0.00
# 53715                None              None    None       None           0.00
# 62261                None              None    None       None           0.00
# 67238                None              None    None       None           0.00
#
#        home_opening_kickoff  qb_epa  xyac_epa  xyac_mean_yardage  \
# 2708                   1.00    0.00       NaN                NaN
# 6446                   0.00   -0.00       NaN                NaN
# 20043                  0.00    0.00       NaN                NaN
# 24234                  0.00    0.00       NaN                NaN
# 26869                  1.00   -0.00       NaN                NaN
# 37245                  0.00    0.00       NaN                NaN
# 39195                  0.00    0.00       NaN                NaN
# 52056                  1.00   -0.00       NaN                NaN
# 53715                  1.00   -0.00       NaN                NaN
# 62261                  1.00    0.00       NaN                NaN
# 67238                  1.00    0.00       NaN                NaN
#
#        xyac_median_yardage  xyac_success  xyac_fd  xpass  pass_oe  \
#        n_offense  n_defense  game_quarter  target  fantasy_rec_yd_pts  \
# 2708       11.00      11.00             4       0                 NaN
# 6446       11.00      11.00             2       0                 NaN
# 20043      11.00      11.00             4       0                 NaN
# 24234      11.00      11.00             2       0                 NaN
# 26869      11.00      11.00             4       0                 NaN
# 37245      11.00      11.00             1       0                 NaN
# 39195       0.00       0.00             3       0                 NaN
# 52056      11.00      11.00             3       0                 NaN
# 53715      11.00      11.00             4       0                 NaN
# 62261      10.00      11.00             1       0                 NaN
# 67238      11.00      11.00             4       0                 NaN
#
#        fantasy_rec_td_pts  fantasy_rec_twoPointConv_pts  fantasy_rec_pts  \
# 2708                    0                             0              NaN
# 6446                    0                             0              NaN
# 20043                   0                             0              NaN
# 24234                   0                             0              NaN
# 26869                   0                             0              NaN
# 37245                   0                             0              NaN
# 39195                   0                             0              NaN
# 52056                   0                             0              NaN
# 53715                   0                             0              NaN
# 62261                   0                             0              NaN
# 67238                   0                             0              NaN
#
#        fantasy_rush_yd_pts  fantasy_rush_td_pts  fantasy_rush_lostFumble_pts  \
# 2708                   NaN                    0                            0
# 6446                   NaN                    0                            0
# 20043                  NaN                    0                            0
# 24234                  NaN                    0                            0
# 26869                  NaN                    0                            0
# 37245                  NaN                    0                            0
# 39195                  NaN                    0                            0
# 52056                  NaN                    0                            0
# 53715                  NaN                    0                            0
# 62261                  NaN                    0                            0
# 67238                  NaN                    0                            0
#
#        fantasy_rush_twoPointConv_pts  fantasy_rush_pts  fantasy_pass_yd_pts  \
# 2708                               0               NaN                  NaN
# 6446                               0               NaN                  NaN
# 20043                              0               NaN                  NaN
# 24234                              0               NaN                  NaN
# 26869                              0               NaN                  NaN
# 37245                              0               NaN                  NaN
# 39195                              0               NaN                  NaN
# 52056                              0               NaN                  NaN
# 53715                              0               NaN                  NaN
# 62261                              0               NaN                  NaN
# 67238                              0               NaN                  NaN
#
#        fantasy_pass_td_pts  fantasy_pass_int_pts  \
# 2708                     0                     0
# 6446                     0                     0
# 20043                    0                     0
# 24234                    0                     0
# 26869                    0                     0
# 37245                    0                     0
# 39195                    0                     0
# 52056                    0                     0
# 53715                    0                     0
# 62261                    0                     0
# 67238                    0                     0
#
#        fantasy_pass_twoPointConv_pts  fantasy_pass_pts
# 2708                               0               NaN
# 6446                               0               NaN
# 20043                              0               NaN
# 24234                              0               NaN
# 26869                              0               NaN
# 37245                              0               NaN
# 39195                              0               NaN
# 52056                              0               NaN
# 53715                              0               NaN
# 62261                              0               NaN
# 67238                              0               NaN

# %%
pbp_expand_df = participation_expander(pbp_enrich_df)
pbp_expand_df[pbp_expand_df['game_id']=='2022_09_TEN_KC'] \
    .sort_values(by=['play_id'], ascending=True) \
    .to_csv(path_or_buf='../nfl_pbp_data/pbp_fantasy_2022_09_TEN_KC.csv')
# Out:
# Splitting personnel.
# Joining split data.

# %%
pbp_expand_df[pbp_expand_df['play_type_nfl'].isin(['RUSH','PASS','SACK'])] \
    .groupby(by=['offense_player_1_id', 'game_id']) \
    .agg({'play_id':'count'}).reset_index()
# Out:
#      offense_player_1_id          game_id  play_id
# 0             00-0022924  2021_01_PIT_BUF       53
# 1             00-0022924   2021_02_LV_PIT       53
# 2             00-0022924  2021_03_CIN_PIT       73
# 3             00-0022924   2021_04_PIT_GB       50
# 4             00-0022924  2021_05_DEN_PIT       48
# ...                  ...              ...      ...
# 2437          00-0038124    2022_04_NE_GB        3
# 2438          00-0038124   2022_05_NYG_GB        4
# 2439          00-0038124   2022_09_GB_DET        9
# 2440          00-0038124   2022_10_DAL_GB       12
# 2441          00-0038124   2022_11_TEN_GB        5
#
# [2442 rows x 3 columns]

# %%
off_agg_df = import_off_agg_data(years=env_dict['seasons'], regular=True, level='season')
off_agg_df.sort_values(by=['season','fantasy_total_pts'], ascending=[True, False])

# %%
# pbp_fantasy_df[pbp_fantasy_df['game_id']=='2022_09_TEN_KC'].sort_values(by=['play_id'], ascending=True) \
#     .to_csv(path_or_buf='data/pbp_fantasy_2022_09_TEN_KC.csv')

# %%
ngs_rush_df = nfl.import_ngs_data(stat_type='rushing', years=env_dict['seasons'])
ngs_rec_df = nfl.import_ngs_data(stat_type='receiving', years=env_dict['seasons'])
ngs_pass_df = nfl.import_ngs_data(stat_type='passing', years=env_dict['seasons'])

# %%
ngs_rush_df[(ngs[[_rush_df['week']==0)&(ngs_rush_df['season_type']=='REG')] \
    .sort_values(by=['season','rush_yards_over_expected_per_att'],ascending=[False,False]).head(200)

# %%
ngs_rush_df[(ngs_rush_df['player_display_name']=='Nick Chubb')& \
            (ngs_rush_df['season_type']=='REG')& \
            (ngs_rush_df['season']==2022)].sort_values(by=['week'],ascending=[False])

# %%
snap_counts_df = nfl.import_snap_counts(env_dict['seasons'])
snap_counts_df.head(1)
# snap_counts_df[(snap_counts_df[''])]

# %%
# combine_df = nfl.import_combine_data(years=env_dict['seasons'])
# combine_df

# %%
# Enrich off_agg_df
off_agg_df['fantasy_total_pts'] = off_agg_df['fantasy_rush_pts'] + \
                                  off_agg_df['fantasy_rec_pts'] + \
                                  off_agg_df['fantasy_pass_pts']
off_agg_df['overall_rank'] = off_agg_df.groupby('season')['fantasy_total_pts'] \
                                       .rank(method='dense', ascending=False) \
                                       .astype(int)
off_agg_df['rush_rank'] = off_agg_df.groupby('season')['fantasy_rush_pts'] \
                                    .rank(method='dense', ascending=False) \
                                    .astype(int)
off_agg_df['rec_rank'] = off_agg_df.groupby('season')['fantasy_rec_pts'] \
                                   .rank(method='dense', ascending=False) \
                                   .astype(int)
off_agg_df['pass_rank'] = off_agg_df.groupby('season')['fantasy_pass_pts'] \
                                    .rank(method='dense', ascending=False) \
                                    .astype(int)
off_agg_df['position_rank'] = off_agg_df.groupby(by=['position','season'])['fantasy_total_pts'] \
                                        .rank(method='dense', ascending=False) \
                                        .astype(int)
off_agg_df['fantasy_total_pts_nextYear'] = off_agg_df.sort_values(by=['player_id','season'], ascending=[True,False]) \
                                                     .groupby(['player_id'])['fantasy_total_pts'].shift(1)
off_agg_df['fantasy_total_pts_nextYearDiff'] = off_agg_df['fantasy_total_pts'] - \
                                               off_agg_df['fantasy_total_pts_nextYear']

off_agg_df[(off_agg_df['position']=='RB')&(off_agg_df['season']==2021)].sort_values(by=['position_rank'], 
                                                                                    ascending=True)

# %%
# Set plot parameters
plot_position = 'WR'
plot_x = 'position_rank'
plot_y = 'fantasy_total_pts_nextYear'
plot_min_x = 0
plot_max_x = 40
bin_step = 5

binning = True

#=================================================

if binning==True:
    plot_df = column_binner(
        off_agg_df[
            (off_agg_df['position'] == plot_position)& \
            (off_agg_df[plot_x] <= plot_max_x)
        ], 
        plot_x, plot_min_x, plot_max_x, bin_step
    )
    plot_x = plot_x + '_binned'
else:
    plot_df = off_agg_df[(off_agg_df['position']==plot_position)&(off_agg_df[plot_x]<=plot_max_x)]
    
sns.set(rc={'figure.figsize':(12,9)})
plot = sns.barplot(
    data=plot_df, 
    x=plot_x, 
    y=plot_y,
    color='grey'
)

# %%
# plot_position = 'WR'
# plot_max_rank = 40
# g = sns.FacetGrid(off_agg_df[(off_agg_df['position_rank']<=plot_max_rank)], 
#                   col="position_rank",
#                   row="fantasy_total_pts_nextYearDiff",
#                   hue="position")
# g.map(sns.lineplot, "position_rank")

# %%
# # Apply custom pivot
# values = ['fantasy_total_pts','overall_rank','position_rank','rush_rank','rec_rank','pass_rank']
# columns = ['season']
# index = ['player_id','player_name','first_name','last_name','position']
# off_agg_pivot_df = custom_pivot(off_agg_df, values, columns, index)
# off_agg_pivot_df

# for column in off_agg_pivot_df.columns:
#     if column[0:1].isdigit():
#         for sub_column in off_agg_pivot_df.columns:
#             if sub_column[0:1].isdigit():
#                 if (column[5:]==sub_column[5:])&(int(column[:4])==(int(sub_column[:4])+1)):
#                     new_col = column + '_prevDiff'
#                     off_agg_pivot_df[new_col] = off_agg_pivot_df[column] - off_agg_pivot_df[sub_column]
#                 elif (column[5:]==sub_column[5:])&((int(column[:4])+1)==int(sub_column[:4])):
#                     new_col = column + '_nextDiff'
#                     off_agg_pivot_df[new_col] = off_agg_pivot_df[column] - off_agg_pivot_df[sub_column]
#                 else: pass
#             else: pass
#     else: pass

# off_agg_melt_df = off_agg_pivot_df.melt(id_vars=index, var_name='variable')
# off_agg_filter_df = off_agg_melt_df[off_agg_melt_df['variable'].str.contains('position_rank', na=False) |
#                                     off_agg_melt_df['variable'].str.contains('pts_nextDiff', na=False) |
#                                     off_agg_melt_df['variable'].str.contains('position_rank_nextDiff', na=False)]
# off_agg_filter_df['new_variable'] = off_agg_filter_df['variable'].str[5:]
# off_agg_repivot_df = pd.pivot_table(off_agg_filter_df, values=['value'], columns=['new_variable'], index=index)
# off_agg_repivot_df = off_agg_repivot_df['value'].reset_index()
# off_agg_repivot_df

# %% [markdown]
# <h2>Data Exploration</h2>

# %%
nfl.import_ngs_data(stat_type='rushing', years=env_dict['seasons'])

# %%
nfl.import_draft_picks([2021])

# %%
nfl.import_officials([2020])

# %%
nfl.import_draft_values()
